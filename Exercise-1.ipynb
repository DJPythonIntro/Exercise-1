# %%
ice_cream_rating = 8

# %%
sleeping_rating = 9

# %%
first_name = input('First name')
last_name = input('Last name')
# Out:
# First name Daniel
# Last name Jarrad

# %%
happiness_rating = (ice_cream_rating + sleeping_rating) / 2

# %%
print(happiness_rating)
# Out:
# 8.5

# %%
type(ice_cream_rating)
# Out:
# int

# %%
type(sleeping_rating)
# Out:
# int

# %%
type(happiness_rating)
# Out:
# float

# %%
type(ice_cream_rating, sleeping_rating, happiness_rating)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_97/1257251702.py in <module>
# ----> 1 type(ice_cream_rating, sleeping_rating, happiness_rating)
#
# TypeError: type.__new__() argument 1 must be str, not int

# %% [markdown]
# Yes, all the data types made sense.

# %%
print('My name is', first_name, 'and I give eating ice cream a rating of ', ice_cream_rating, ' out of 10')
print('I am', first_name + ' ' + last_name, 'and my sleeping enjoyment rating is ', sleeping_rating, 'out of 10')
print('Based on the factors above, my happiness rating is ', happiness_rating, 'out of 10 or 85.0%')
# Out:
# My name is Daniel and I give eating ice cream a rating of  8  out of 10
# I am Daniel Jarrad and my sleeping enjoyment rating is  9 out of 10
# Based on the factors above, my happiness rating is  8.5 out of 10 or 85.0%
